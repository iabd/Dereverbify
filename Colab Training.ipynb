# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
driveDir="/content/gdrive/My Drive/Research/Dereverbify"
import sys
sys.path.insert(0, driveDir)
# !pip3 install pyroomacoustics

# %%
# !nvidia-smi
# Out:
# Fri Apr  9 16:07:02 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.67       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    24W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import argparse, json, torch, pdb, librosa, os
from glob import glob
import numpy as np
from dataset import TrainDataset, TestDataset
from torch.utils.data import DataLoader
import torch.optim as optim
from tqdm import tqdm
import logging
from utils import saveSpectrogram
from torchvision import transforms
from PIL import Image
from unet import UNet
from torch.utils.tensorboard import SummaryWriter
from loss import MixLoss
from utils import countParams
from train import train, validate
with open(os.path.join(driveDir, "config.json")) as f:
  data=f.read()

config=json.loads(data)
trainConfig=config["trainConfig"]
dataConfig=config["dataConfig"]
trainLossConfig=config["trainLossConfig"]
valLossConfig=config["valLossConfig"]

# %%
train(**trainConfig, dataConfig=dataConfig, trainLossConfig=trainLossConfig, valLossConfig=valLossConfig)
# Out:
# ...
# Epoch 1/1000:   0%|          | 0/1000 [03:56<?, ?audio/s, loss (batch)=0.398]
#
#
# Validation round:   0%|          | 0/100 [00:00<?, ?batch/s]
#
#
# Validation round:   1%|          | 1/100 [00:04<07:14,  4.39s/batch]
#
#
# Validation round:   3%|▎         | 3/100 [00:04<04:59,  3.09s/batch]
#
#
# Validation round:   5%|▌         | 5/100 [00:04<03:27,  2.19s/batch]
#
#
# Validation round:   7%|▋         | 7/100 [00:04<02:24,  1.55s/batch]
#
#
# Validation round:   9%|▉         | 9/100 [00:08<02:28,  1.63s/batch]
#
#
# Validation round:  11%|█         | 11/100 [00:08<01:43,  1.16s/batch]
#
#
# Validation round:  13%|█▎        | 13/100 [00:08<01:12,  1.20batch/s]
#
#
# Validation round:  15%|█▌        | 15/100 [00:08<00:51,  1.65batch/s]
#
#
# Validation round:  17%|█▋        | 17/100 [00:09<00:36,  2.25batch/s]
#
#
# Validation round:  19%|█▉        | 19/100 [00:09<00:26,  3.01batch/s]
#
#
# Validation round:  21%|██        | 21/100 [00:13<01:09,  1.14batch/s]
#
#
# ...
